# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt
import os
from pathlib import Path

# %%
csv_path = Path("../datasets/ccdi_clinical_participants.csv").resolve()
print(csv_path, csv_path.exists())
# Out:
# C:\Users\quinn\Desktop\Bayesian Modeling for Generative AI\fpbml\final_project_bayesian\datasets\ccdi_clinical_participants.csv True

# %%
ccdi_patients_data = pd.read_csv(csv_path, index_col=0)
print(ccdi_patients_data.head(5))
ccdi_patients_data.describe()
# Out:
#                  Study ID Sex at Birth                      Race  \
# Participant ID
# 0E61LZ          phs002790         Male                   Unknown
# PANLMU          phs002790       Female                     White
# PARGFV          phs002790         Male  Hispanic or Latino;White
# PAUTVR          phs002790         Male  Hispanic or Latino;White
# PBBHCR          phs002790       Female                     White
#
#                                                         Diagnosis  \
# Participant ID
# 0E61LZ                                                        NaN
# PANLMU                                            Meningioma, NOS
# PARGFV          Precursor B-cell lymphoblastic leukemia Pro-B ...
# PAUTVR          High-grade glioma, NOS or NEC;High-Grade Gliom...
# PBBHCR                                    Medulloepithelioma, NOS
#
#                                           Diagnosis Anatomic Site  \
# Participant ID
# ...
